# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('eventlog.csv')
print(df)
# Out:
#                    date  eventID  account          ip service  \
# 0       2018/04/19 9:27     5140   asapc$   10.0.9.15     DC$
# 1       2018/04/19 9:27     5140   asapc$   10.0.9.15     DC$
# 2       2018/04/19 9:28     5140   asapc$   10.0.9.15  krbtgt
# 3       2018/04/19 9:28     5140   asapc$   10.0.9.15  krbtgt
# 4       2018/04/19 9:28     5140   asapc$   10.0.9.15     DC$
# 5       2018/04/19 9:28     5140   asapc$   10.0.9.15     DC$
# 6       2018/04/19 9:28     5140   asapc$   10.0.9.15     DC$
# 7       2018/04/19 9:28     5140   asapc$   10.0.9.15     DC$
# 8       2018/04/19 9:39     5140   asapc$   10.0.9.15     DC$
# 9       2018/04/19 9:39     5140   asapc$   10.0.9.15     DC$
# 10      2018/04/19 9:43     5140   asapc$   10.0.9.15     DC$
# 11      2018/04/19 9:43     5140   asapc$   10.0.9.15     DC$
# 12      2018/04/19 9:51     5140   asapc$   10.0.9.15       -
# 13      2018/04/19 9:51     5140   asapc$   10.0.9.15       -
# 14      2018/04/19 9:58     5140   asapc$   10.0.9.15     DC$
# 15      2018/04/19 9:58     5140   asapc$   10.0.9.15     DC$
# 16     2018/04/19 10:13     5140   asapc$   10.0.9.15     DC$
# 17     2018/04/19 10:13     5140   asapc$   10.0.9.15     DC$
# 18     2018/04/19 10:28     5140   asapc$   10.0.9.15     DC$
# 19     2018/04/19 10:28     5140   asapc$   10.0.9.15     DC$
# 20     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 21     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 22     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 23     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 24     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 25     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 26     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 27     2018/04/19 16:54     5140   asapc$   10.0.9.15  ASAPC$
# 28     2018/04/19 16:55     5140   asapc$   10.0.9.15     DC$
# 29     2018/04/19 16:55     5140   asapc$   10.0.9.15     DC$
# ...                 ...      ...      ...         ...     ...
# 48020  2018/04/06 12:51     4674  dcadmin  10.0.19.52     DC$
# 48021  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48022  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48023  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48024  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48025  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48026  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48027  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48028  2018/04/06 12:51     4688  dcadmin  10.0.19.52     DC$
# 48029  2018/04/06 12:52     4688  dcadmin  10.0.19.52     DC$
# 48030  2018/04/06 12:52     4674  dcadmin  10.0.19.52     DC$
# 48031  2018/04/06 12:52     4674  dcadmin  10.0.19.52     DC$
# 48032  2018/04/06 12:52     4674  dcadmin  10.0.19.52     DC$
# 48033  2018/04/06 12:52     4674  dcadmin  10.0.19.52     DC$
# 48034  2018/04/06 12:52     4688  dcadmin  10.0.19.52     DC$
# 48035  2018/04/06 12:52     4688  dcadmin  10.0.19.52     DC$
# 48036  2018/04/06 12:52     4688  dcadmin  10.0.19.52     DC$
# 48037  2018/04/06 12:52     4688  dcadmin  10.0.19.52     DC$
# 48038  2018/04/06 12:52     4688  dcadmin  10.0.19.52     DC$
# 48039  2018/04/06 12:53     4688  dcadmin  10.0.19.52     DC$
# 48040  2018/04/06 12:53     4688  dcadmin  10.0.19.52     DC$
# 48041  2018/04/06 12:53     4688  dcadmin  10.0.19.52     DC$
# 48042  2018/04/12 18:28     4688    asabe   10.0.9.15     DC$
# 48043  2018/04/12 18:28     4688    asabe   10.0.9.15     DC$
# 48044  2018/04/12 18:29     4688    asabe   10.0.9.15     DC$
# 48045  2018/04/12 18:29     4688    asabe   10.0.9.15     DC$
# 48046  2018/04/12 18:29     4688    asabe   10.0.9.15     DC$
# 48047  2018/04/12 18:34     4688    asabe   10.0.9.15     NaN
# 48048  2018/04/12 18:51     4688  dcadmin  10.0.19.52       -
# 48049  2018/04/12 18:51     4688  dcadmin  10.0.19.52       -
#
#                                   process  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# ...                                   ...
# 48020   c:\windows\system32\wbem\wmic.exe
# 48021         c:\windows\system32\net.exe
# 48022        c:\windows\system32\net1.exe
# 48023         c:\windows\system32\net.exe
# 48024        c:\windows\system32\net1.exe
# 48025         c:\windows\system32\net.exe
# 48026        c:\windows\system32\net1.exe
# 48027         c:\windows\system32\net.exe
# 48028        c:\windows\system32\net1.exe
# 48029     c:\windows\system32\netstat.exe
# 48030     c:\windows\system32\netstat.exe
# 48031     c:\windows\system32\netstat.exe
# 48032     c:\windows\system32\netstat.exe
# 48033     c:\windows\system32\netstat.exe
# 48034         c:\windows\system32\cmd.exe
# 48035    c:\windows\system32\schtasks.exe
# 48036         c:\windows\system32\cmd.exe
# 48037    c:\windows\system32\schtasks.exe
# 48038    c:\windows\system32\tasklist.exe
# 48039    c:\windows\system32\schtasks.exe
# 48040        c:\windows\system32\find.exe
# 48041          c:\windows\system32\at.exe
# 48042    c:\windows\system32\ipconfig.exe
# 48043     c:\windows\system32\netstat.exe
# 48044  c:\windows\system32\systeminfo.exe
# 48045      c:\windows\system32\whoami.exe
# 48046   c:\windows\system32\wbem\wmic.exe
# 48047      c:\windows\system32\whoami.exe
# 48048          c:\windows\system32\at.exe
# 48049    c:\windows\system32\tasklist.exe
#
#                                               objectname  sharedname   target
# 0                                                    NaN    \\*\ipc$    train
# 1                                                    NaN         NaN    train
# 2                                                    NaN    \\*\ipc$    train
# 3                                                    NaN         NaN    train
# 4                                                    NaN    \\*\ipc$    train
# 5                                                    NaN         NaN    train
# 6                                                    NaN  \\*\sysvol    train
# 7                                                    NaN         NaN    train
# 8                                                    NaN    \\*\ipc$    train
# 9                                                    NaN         NaN    train
# 10                                                   NaN    \\*\ipc$    train
# 11                                                   NaN         NaN    train
# 12                                                   NaN    \\*\ipc$    train
# 13                                                   NaN         NaN    train
# 14                                                   NaN    \\*\ipc$    train
# 15                                                   NaN         NaN    train
# 16                                                   NaN    \\*\ipc$    train
# 17                                                   NaN         NaN    train
# 18                                                   NaN    \\*\ipc$    train
# 19                                                   NaN         NaN    train
# 20                                                   NaN    \\*\ipc$    train
# 21                                                   NaN         NaN    train
# 22                                                   NaN    \\*\ipc$    train
# 23                                                   NaN         NaN    train
# 24                                                   NaN    \\*\ipc$    train
# 25                                                   NaN         NaN    train
# 26                                                   NaN  \\*\sysvol    train
# 27                                                   NaN         NaN    train
# 28                                                   NaN    \\*\ipc$    train
# 29                                                   NaN         NaN    train
# ...                                                  ...         ...      ...
# 48020                                                  -         NaN  outlier
# 48021                                                NaN         NaN  outlier
# 48022                                                NaN         NaN  outlier
# 48023                                                NaN         NaN  outlier
# 48024                                                NaN         NaN  outlier
# 48025                                                NaN         NaN  outlier
# 48026                                                NaN         NaN  outlier
# 48027                                                NaN         NaN  outlier
# 48028                                                NaN         NaN  outlier
# 48029                                                NaN         NaN  outlier
# 48030  \registry\machine\system\controlset001\service...         NaN  outlier
# 48031                                                  -         NaN  outlier
# 48032  \registry\machine\system\controlset001\service...         NaN  outlier
# 48033                                                  -         NaN  outlier
# 48034                                                NaN         NaN  outlier
# 48035                                                NaN         NaN  outlier
# 48036                                                NaN         NaN  outlier
# 48037                                                NaN         NaN  outlier
# 48038                                                NaN         NaN  outlier
# 48039                                                NaN         NaN  outlier
# 48040                                                NaN         NaN  outlier
# 48041                                                NaN         NaN  outlier
# 48042                                                NaN         NaN  outlier
# 48043                                                NaN         NaN  outlier
# 48044                                                NaN         NaN  outlier
# 48045                                                NaN         NaN  outlier
# 48046                                                NaN         NaN  outlier
# 48047                                                NaN         NaN  outlier
# 48048                                                NaN         NaN  outlier
# 48049                                                NaN         NaN  outlier
#
# [48050 rows x 9 columns]

# %% [markdown]
# One-class SVM

# %%
def learning(eventid, df, nu, gamma):
    
    df = df[df.eventID == eventid]
    data_dummies = pd.get_dummies(df.iloc[:,1:])
    data_dummies = pd.concat([df.iloc[:,0], data_dummies], axis=1)
    print(eventid)

    if 'train' not in df.target.values:
        print('No train value in the target column')
        print('')
        return

    if 'test' not in df.target.values:
        print('No test value in the target column')
        print('')
        return
    
    if 'outlier' not in df.target.values:
        print('No outlier value in the target column')
        print('')
        return

    data_normal = data_dummies[data_dummies.target_train == 1]
    data_test = data_dummies[data_dummies.target_test == 1]
    data_outliers = data_dummies[data_dummies.target_outlier == 1]
    X_train = data_normal.ix[:, 1:-4].values
    X_test = data_test.ix[:, 1:-4].values
    X_outliers = data_outliers.ix[:, 1:-4].values
    
    X_all = data_dummies.ix[:, 1:-4].values
    X_index = data_dummies.ix[:, -3:].values
    
    clf = svm.OneClassSVM(nu=nu, kernel="rbf", gamma=gamma)
    clf.fit(X_train)
    
    #n_correct_test is True Negative
    #n_error_test is False Positive
    #n_correct_outliers is True Positive
    #n_error_outliers is False Negative

    X_pred_train = clf.predict(X_train)
    X_pred_test = clf.predict(X_test)
    X_pred_outliers = clf.predict(X_outliers)
    n_correct_train = X_pred_train[X_pred_train == 1].size
    n_error_train = X_pred_train[X_pred_train == -1].size
    n_correct_test = X_pred_test[X_pred_test == 1].size
    n_error_test = X_pred_test[X_pred_test == -1].size
    n_correct_outliers = X_pred_outliers[X_pred_outliers == -1].size
    n_error_outliers = X_pred_outliers[X_pred_outliers == 1].size
    recall = n_correct_outliers / (n_correct_outliers + n_error_outliers)
    precision = n_correct_outliers / (n_correct_outliers + n_error_test)
    specificity = n_correct_test / (n_correct_test + n_error_test)
    accuracy = (n_correct_test + n_correct_outliers) / (n_correct_test + n_error_test + n_correct_outliers + n_error_outliers)
    f_value = (2 * n_correct_outliers) / (2 * n_correct_outliers + n_error_test + n_error_outliers)
    
    print('svm.OneClassSVM(nu=' + str(nu) + ', kernel="rbf", gamma=' + str(gamma) + ')')
    print('Training Correct: ' + str(n_correct_train))
    print('Training Error: ' + str(n_error_train))
    print('True Negative: ' + str(n_correct_test))
    print('False Positive: ' + str(n_error_test))
    print('True Positive: ' + str(n_correct_outliers))
    print('False Negative: ' + str(n_error_outliers))
    print('Recall: ' + str(recall))
    print('Precision: ' + str(precision))
    print('Specificity: ' + str(specificity))
    print('Accuracy: ' + str(accuracy))
    print('F_Value: ' + str(f_value))
    print('')
    
    X_train_result = np.concatenate((df[df['target'] == 'train'], X_pred_train[np.newaxis, :].T), axis=1)
    X_test_result = np.concatenate((df[df['target'] == 'test'], X_pred_test[np.newaxis, :].T), axis=1)
    X_outliers_result = np.concatenate((df[df['target'] == 'outlier'], X_pred_outliers[np.newaxis, :].T), axis=1)

    with open('X_train_result' + str(eventid) + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerows(X_train_result)
    
    with open('X_test_result' + str(eventid) + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerows(X_test_result)

    with open('X_outliers_result' + str(eventid) + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerows(X_outliers_result)
        
    #print('PCA')
    #pca = PCA(n_components=2)
    #X_pca = pca.fit_transform(X_all)

    #plt.figure()
    #plt.scatter(X_pca[:,0], X_pca[:,1], c=X_index)
    #plt.title('Red:' + data_dummies.columns[-3] + '  Green:' + data_dummies.columns[-2] + '  Blue:' + data_dummies.columns[-1])
    #plt.show()

# %%
nu_list = [0.1, 0.01, 0.001]
gamma_list = [0.1, 0.01, 0.001]

for nu in nu_list:
    for gamma in gamma_list:
        #learning(4672, df, nu, gamma)
        #learning(4673, df, nu, gamma)
        #learning(4674, df, nu, gamma)
        learning(4688, df, nu, gamma)
        #learning(4768, df, nu, gamma)
        #learning(4769, df, nu, gamma)
        #learning(5140, df, nu, gamma)
# Out:
# 4688
# svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)
# Training Correct: 2788
# Training Error: 1030
# True Negative: 42
# False Positive: 34
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.5853658536585366
# Specificity: 0.5526315789473685
# Accuracy: 0.7258064516129032
# F_Value: 0.7384615384615385
#
# 4688
# svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.01)
# Training Correct: 2762
# Training Error: 1056
# True Negative: 54
# False Positive: 22
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.6857142857142857
# Specificity: 0.7105263157894737
# Accuracy: 0.8225806451612904
# F_Value: 0.8135593220338984
#
# 4688
# svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.001)
# Training Correct: 2857
# Training Error: 961
# True Negative: 45
# False Positive: 31
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.6075949367088608
# Specificity: 0.5921052631578947
# Accuracy: 0.75
# F_Value: 0.7559055118110236
#
# 4688
# svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.1)
# Training Correct: 3748
# Training Error: 70
# True Negative: 70
# False Positive: 6
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.8888888888888888
# Specificity: 0.9210526315789473
# Accuracy: 0.9516129032258065
# F_Value: 0.9411764705882353
#
# 4688
# svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01)
# Training Correct: 3738
# Training Error: 80
# True Negative: 63
# False Positive: 13
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.7868852459016393
# Specificity: 0.8289473684210527
# Accuracy: 0.8951612903225806
# F_Value: 0.8807339449541285
#
# 4688
# svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.001)
# Training Correct: 3748
# Training Error: 70
# True Negative: 69
# False Positive: 7
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.8727272727272727
# Specificity: 0.9078947368421053
# Accuracy: 0.9435483870967742
# F_Value: 0.9320388349514563
#
# 4688
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.1)
# Training Correct: 3763
# Training Error: 55
# True Negative: 70
# False Positive: 6
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.8888888888888888
# Specificity: 0.9210526315789473
# Accuracy: 0.9516129032258065
# F_Value: 0.9411764705882353
#
# 4688
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.01)
# Training Correct: 3749
# Training Error: 69
# True Negative: 66
# False Positive: 10
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.8275862068965517
# Specificity: 0.868421052631579
# Accuracy: 0.9193548387096774
# F_Value: 0.9056603773584906
#
# 4688
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.001)
# Training Correct: 3695
# Training Error: 123
# True Negative: 66
# False Positive: 10
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.8275862068965517
# Specificity: 0.868421052631579
# Accuracy: 0.9193548387096774
# F_Value: 0.9056603773584906

# %%
learning(4688, df, 0.001, 0.1)
# Out:
# 4688
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.1)
# Training Correct: 3763
# Training Error: 55
# True Negative: 70
# False Positive: 6
# True Positive: 48
# False Negative: 0
# Recall: 1.0
# Precision: 0.8888888888888888
# Specificity: 0.9210526315789473
# Accuracy: 0.9516129032258065
# F_Value: 0.9411764705882353
